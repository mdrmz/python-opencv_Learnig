# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('a.jpg')

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is D4D4-19F0
#
#  Directory of C:\Users\MEHMET\openCV\udemy\numpy  ve
#
# 19.11.2022  13:06    <DIR>          .
# 19.11.2022  13:06    <DIR>          ..
# 19.11.2022  13:03    <DIR>          .ipynb_checkpoints
# 17.11.2021  11:06           132.324 a.jpg
# 14.11.2021  15:37           132.741 b.jpg
# 17.11.2021  11:06           132.202 c.jpg
# 19.11.2022  13:06           993.328 Untitled1.ipynb
#                4 File(s)      1.390.595 bytes
#                3 Dir(s)  46.830.088.192 bytes free

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x260AACC6040>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
 pic_arr = np.asarray(pic) # burda fotyuu arya döndü

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(pic)

# %%
pic_red = pic_arr.copy()

# %%
pic_red.shape
# Out:
# (720, 1280, 3)

# %%
pic_red[:,:,0]   # BURADA 0 255 YAPARAK KIRMIZI YAPTIK
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
pic_red
# Out:
# array([[[255, 201, 200],
#         [255, 201, 200],
#         [255, 202, 201],
#         ...,
#         [255, 129, 131],
#         [255, 129, 132],
#         [255, 130, 133]],
#
#        [[255, 203, 202],
#         [255, 203, 202],
#         [255, 203, 202],
#         ...,
#         [255, 128, 130],
#         [255, 128, 131],
#         [255, 128, 131]],
#
#        [[255, 203, 202],
#         [255, 203, 202],
#         [255, 203, 202],
#         ...,
#         [255, 128, 130],
#         [255, 128, 131],
#         [255, 128, 131]],
#
#        ...,
#
#        [[255,  72,  76],
#         [255,  72,  76],
#         [255,  72,  76],
#         ...,
#         [255, 203, 206],
#         [255, 202, 205],
#         [255, 202, 205]],
#
#        [[255,  71,  75],
#         [255,  71,  75],
#         [255,  70,  74],
#         ...,
#         [255, 202, 205],
#         [255, 202, 205],
#         [255, 203, 206]],
#
#        [[255,  70,  75],
#         [255,  69,  73],
#         [255,  68,  72],
#         ...,
#         [255, 201, 204],
#         [255, 201, 204],
#         [255, 202, 205]]], dtype=uint8)

# %%
plt.imshow(pic_red)

# %%
plt.imshow(pic_red[:,:,0],cmap = 'gray')
